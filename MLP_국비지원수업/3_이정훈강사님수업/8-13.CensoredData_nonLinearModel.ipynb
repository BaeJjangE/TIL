# %% [markdown]
# !pip3 install scikit-survival<br>
# !pip3 install eli5

# %%
# !pip3 install eli5
# Out:
# Collecting eli5
#   Downloading eli5-0.11.0-py2.py3-none-any.whl (106 kB)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\user\anaconda3\lib\site-packages (from eli5) (1.20.3)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from eli5) (2.11.3)
# Requirement already satisfied: scikit-learn>=0.20 in c:\users\user\anaconda3\lib\site-packages (from eli5) (1.0.2)
# Requirement already satisfied: graphviz in c:\users\user\anaconda3\lib\site-packages (from eli5) (0.19.2)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\user\anaconda3\lib\site-packages (from eli5) (0.8.9)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from eli5) (1.7.1)
# Requirement already satisfied: attrs>16.0.0 in c:\users\user\anaconda3\lib\site-packages (from eli5) (21.2.0)
# Requirement already satisfied: six in c:\users\user\anaconda3\lib\site-packages (from eli5) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn>=0.20->eli5) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn>=0.20->eli5) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\user\anaconda3\lib\site-packages (from jinja2->eli5) (1.1.1)
# Installing collected packages: eli5
# Successfully installed eli5-0.11.0

# %%
# !pip3 install scikit-survival
# Out:
# Requirement already satisfied: scikit-survival in c:\users\user\anaconda3\lib\site-packages (0.16.0)
# Requirement already satisfied: ecos in c:\users\user\anaconda3\lib\site-packages (from scikit-survival) (2.0.7.post1)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\lib\site-packages (from scikit-survival) (1.1.0)
# Collecting scikit-learn<0.25,>=0.24.0
#   Downloading scikit_learn-0.24.2-cp39-cp39-win_amd64.whl (6.9 MB)
# Requirement already satisfied: pandas>=0.25 in c:\users\user\anaconda3\lib\site-packages (from scikit-survival) (1.3.4)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from scikit-survival) (1.20.3)
# Requirement already satisfied: numexpr in c:\users\user\anaconda3\lib\site-packages (from scikit-survival) (2.7.3)
# Requirement already satisfied: scipy!=1.3.0,>=1.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-survival) (1.7.1)
# Requirement already satisfied: osqp!=0.6.0,!=0.6.1 in c:\users\user\anaconda3\lib\site-packages (from scikit-survival) (0.6.2.post5)
# Requirement already satisfied: qdldl in c:\users\user\anaconda3\lib\site-packages (from osqp!=0.6.0,!=0.6.1->scikit-survival) (0.1.5.post2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.25->scikit-survival) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.25->scikit-survival) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25->scikit-survival) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn<0.25,>=0.24.0->scikit-survival) (2.2.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
# Successfully installed scikit-learn-0.24.2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline 
# 첫 번째 줄에서 %matplotlib inline 의 역할은 notebook을 실행한 브라우저에서 바로 그림을 볼 수 있게 해주는 것

출처: https://korbillgates.tistory.com/85 [생물정보학자의 블로그]

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder

from sksurv.datasets import load_gbsg2
from sksurv.preprocessing import OneHotEncoder
from sksurv.ensemble import RandomSurvivalForest

# %% [markdown]
# 예제데이터 불러오기

# %%
X, y = load_gbsg2()

# %%
X.head()
# Out:
#     age  estrec horTh menostat  pnodes  progrec tgrade  tsize
# 0  70.0    66.0    no     Post     3.0     48.0     II   21.0
# 1  56.0    77.0   yes     Post     7.0     61.0     II   12.0
# 2  58.0   271.0   yes     Post     9.0     52.0     II   35.0
# 3  59.0    29.0   yes     Post     4.0     60.0     II   17.0
# 4  73.0    65.0    no     Post     1.0     26.0     II   35.0

# %%
y
# Out:
# array([( True, 1814.), ( True, 2018.), ( True,  712.), ( True, 1807.),
#        ( True,  772.), ( True,  448.), (False, 2172.), (False, 2161.),
#        ( True,  471.), (False, 2014.), ( True,  577.), ( True,  184.),
#        (False, 1840.), (False, 1842.), (False, 1821.), ( True, 1371.),
#        ( True,  707.), (False, 1743.), (False, 1781.), ( True,  865.),
#        ( True, 1684.), (False, 1701.), (False, 1701.), (False, 1693.),
#        ( True,  379.), ( True, 1105.), ( True,  548.), ( True, 1296.),
#        (False, 1483.), (False, 1570.), (False, 1469.), (False, 1472.),
#        (False, 1342.), (False, 1349.), ( True, 1162.), (False, 1342.),
#        ( True,  797.), (False, 1232.), (False, 1230.), (False, 1205.),
#        (False, 1090.), (False, 1095.), ( True,  449.), (False,  972.),
#        (False,  825.), (False, 2438.), (False, 2233.), ( True,  286.),
#        (False, 1861.), ( True, 1080.), ( True, 1521.), (False, 1693.),
#        ( True, 1528.), ( True,  169.), ( True,  272.), ( True,  731.),
#        (False, 2059.), (False, 1853.), (False, 1854.), (False, 1645.),
#        ( True,  544.), (False, 1666.), ( True,  353.), (False, 1791.),
#        (False, 1685.), ( True,  191.), ( True,  370.), ( True,  173.),
#        ( True,  242.), ( True,  420.), ( True,  438.), (False, 1624.),
#        ( True, 1036.), ( True,  359.), ( True,  171.), ( True,  959.),
#        (False, 1351.), ( True,  486.), ( True,  525.), ( True,  762.),
#        ( True,  175.), (False, 1195.), ( True,  338.), (False, 1125.),
#        (False,  916.), (False,  972.), (False,  867.), ( True,  249.),
#        ( True,  281.), (False,  758.), ( True,  377.), (False, 1976.),
#        (False, 2539.), (False, 2467.), ( True,  876.), (False, 2132.),
#        ( True,  426.), ( True,  554.), ( True, 1246.), (False, 1926.),
#        ( True, 1207.), (False, 1852.), ( True, 1174.), (False, 1250.),
#        ( True,  530.), (False, 1502.), (False, 1364.), ( True, 1170.),
#        (False, 1729.), (False, 1642.), ( True, 1218.), (False, 1358.),
#        ( True,  360.), ( True,  550.), (False,  857.), (False,  768.),
#        (False,  858.), (False,  770.), ( True,  679.), ( True, 1164.),
#        ( True,  350.), ( True,  578.), ( True, 1460.), (False, 1434.),
#        ( True, 1763.), ( True,  889.), ( True,  357.), ( True,  547.),
#        (False, 1722.), (False, 2372.), ( True, 2030.), ( True, 1002.),
#        ( True, 1280.), ( True,  338.), ( True,  533.), (False,  168.),
#        (False, 1169.), ( True, 1675.), (False, 1862.), (False,  629.),
#        (False, 1167.), ( True,  495.), (False,  967.), (False, 1720.),
#        ( True,  598.), ( True,  392.), (False, 1502.), (False,  229.),
#        (False,  310.), (False, 1296.), (False,  488.), (False,  942.),
#        (False,  570.), (False, 1177.), (False, 1113.), ( True,  288.),
#        (False,  723.), ( True,  403.), ( True, 1225.), ( True,  338.),
#        ( True, 1337.), ( True, 1420.), (False, 2048.), ( True,  600.),
#        (False, 1765.), ( True,  491.), ( True,  305.), (False, 1582.),
#        (False, 1771.), ( True,  960.), ( True,  571.), (False,  675.),
#        ( True,  285.), (False, 1472.), ( True, 1279.), (False,  148.),
#        (False, 1863.), (False, 1933.), ( True,  358.), (False,  734.),
#        ( True, 2372.), (False, 2563.), (False, 2372.), ( True, 1989.),
#        ( True, 2015.), (False, 1956.), ( True,  945.), (False, 2153.),
#        ( True,  838.), ( True,  113.), (False, 1833.), (False, 1722.),
#        ( True,  241.), ( True, 1352.), (False, 1702.), (False, 1222.),
#        (False, 1089.), (False, 1243.), ( True,  579.), ( True, 1043.),
#        (False, 2234.), (False, 2297.), (False, 2014.), ( True,  518.),
#        (False,  940.), (False,  766.), ( True,  251.), (False, 1959.),
#        (False, 1897.), ( True,  160.), (False,  970.), (False,  892.),
#        (False,  753.), ( True,  348.), ( True,  275.), ( True, 1329.),
#        ( True, 1193.), ( True,  698.), ( True,  436.), ( True,  552.),
#        ( True,  564.), (False, 2239.), (False, 2237.), ( True,  529.),
#        (False, 1820.), (False, 1756.), ( True,  515.), ( True,  272.),
#        ( True,  891.), (False, 1356.), (False, 1352.), (False, 1077.),
#        ( True,  675.), (False,  855.), (False,  740.), (False, 2551.),
#        ( True,  754.), ( True,  819.), ( True, 1280.), (False, 2388.),
#        (False, 2296.), (False, 1884.), ( True, 1059.), (False,  859.),
#        (False, 1109.), ( True, 1192.), ( True, 1806.), ( True,  500.),
#        ( True, 1589.), ( True, 1463.), (False, 1826.), (False, 1231.),
#        (False, 1117.), ( True,  836.), (False, 1222.), (False,  663.),
#        ( True,  722.), (False,  322.), ( True, 1150.), ( True,  446.),
#        (False, 1855.), ( True,  238.), (False, 1838.), (False, 1826.),
#        ( True, 1093.), (False, 2051.), ( True,  370.), ( True,  861.),
#        ( True, 1587.), ( True,  552.), (False, 2353.), (False, 2471.),
#        ( True,  893.), ( True, 2093.), (False, 2612.), ( True,  956.),
#        (False, 1637.), (False, 2456.), (False, 2227.), ( True, 1601.),
#        (False, 1841.), (False, 2177.), (False, 2052.), (False,  973.),
#        (False, 2156.), (False, 1499.), (False, 2030.), ( True,  573.),
#        (False, 1666.), (False, 1979.), (False, 1786.), (False, 1847.),
#        (False, 2009.), (False, 1926.), (False, 1490.), ( True,  233.),
#        (False, 1240.), (False, 1751.), (False, 1878.), (False, 1171.),
#        (False, 1751.), (False, 1756.), ( True,  714.), (False, 1505.),
#        ( True,  776.), (False, 1443.), (False, 1317.), (False,  870.),
#        ( True,  859.), ( True,  223.), (False, 1212.), (False, 1119.),
#        (False,  740.), (False, 1062.), (False,    8.), (False,  936.),
#        (False,  740.), ( True,  632.), (False, 1760.), (False, 1013.),
#        (False,  779.), ( True,  375.), (False, 1323.), (False, 1233.),
#        (False,  986.), (False,  650.), (False,  628.), (False, 1866.),
#        ( True,  491.), ( True, 1918.), ( True,   72.), ( True, 1140.),
#        ( True,  799.), ( True, 1105.), ( True,  548.), ( True,  227.),
#        (False, 1838.), (False, 1833.), ( True,  550.), ( True,  426.),
#        (False, 1834.), (False, 1604.), (False,  772.), ( True, 1146.),
#        ( True,  371.), ( True,  883.), (False, 1735.), ( True,  554.),
#        ( True,  790.), (False, 1340.), ( True,  490.), (False, 1557.),
#        ( True,  594.), (False,  828.), ( True,  594.), (False,  841.),
#        (False,  695.), (False, 2556.), ( True, 1753.), ( True,  417.),
#        ( True,  956.), (False, 1846.), (False, 1703.), (False, 1720.),
#        (False, 1355.), (False, 1603.), ( True,  476.), (False, 1350.),
#        (False, 1341.), (False, 2449.), ( True, 2286.), ( True,  456.),
#        ( True,  536.), ( True,  612.), ( True, 2034.), ( True, 1990.),
#        ( True, 2456.), (False, 2205.), ( True,  544.), ( True,  336.),
#        (False, 2057.), ( True,  575.), (False, 2011.), ( True,  537.),
#        (False, 2217.), ( True, 1814.), ( True,  890.), (False, 1114.),
#        (False,  974.), (False,  296.), (False, 2320.), ( True,  795.),
#        ( True,  867.), (False, 1703.), ( True,  670.), ( True,  981.),
#        (False, 1094.), ( True,  755.), ( True, 1388.), ( True, 1387.),
#        ( True,  535.), (False, 1653.), (False, 1904.), (False, 1868.),
#        (False, 1767.), ( True,  855.), ( True, 1157.), (False, 1869.),
#        (False, 1152.), (False, 1401.), (False,  918.), ( True,  745.),
#        (False, 1283.), ( True, 1481.), (False, 1807.), ( True,  542.),
#        (False, 1441.), (False, 1277.), (False, 1486.), (False,  273.),
#        ( True,  177.), ( True,  545.), (False, 1185.), (False,  631.),
#        (False,  995.), (False, 1088.), (False,  877.), (False,  798.),
#        (False, 2380.), ( True, 1679.), ( True,  498.), (False, 2138.),
#        (False, 2175.), (False, 2271.), (False,   17.), ( True,  964.),
#        ( True,  540.), ( True,  747.), ( True,  650.), ( True,  410.),
#        ( True,  624.), (False, 1560.), ( True,  455.), (False, 1629.),
#        (False, 1730.), (False, 1483.), ( True,  687.), ( True,  308.),
#        ( True,  563.), (False,   46.), (False, 2144.), ( True,  344.),
#        (False,  945.), (False, 1905.), ( True,  855.), (False, 2370.),
#        (False,  853.), (False,  692.), ( True,  475.), (False, 2195.),
#        (False,  758.), ( True,  648.), (False,  761.), (False,  596.),
#        ( True,  195.), ( True,  473.), (False,  747.), (False, 2659.),
#        ( True, 1977.), (False, 2401.), (False, 1499.), (False, 1856.),
#        ( True,  595.), (False, 2148.), (False, 2126.), ( True, 1975.),
#        ( True, 1641.), (False, 1717.), (False, 1858.), (False, 2049.),
#        ( True, 1502.), (False, 1922.), (False, 1818.), (False, 1100.),
#        (False, 1499.), ( True,  359.), (False, 1645.), (False, 1356.),
#        (False, 1632.), (False,  967.), (False, 1091.), ( True,  918.),
#        ( True,  557.), ( True, 1219.), (False, 2170.), ( True,  729.),
#        ( True, 1449.), ( True,  991.), ( True,  481.), (False, 1655.),
#        ( True,  857.), ( True,  369.), (False, 1627.), (False, 1578.),
#        ( True,  732.), ( True,  460.), (False, 1208.), ( True,  730.),
#        (False,  722.), (False,  717.), (False,  651.), (False,  637.),
#        (False,  615.), (False,   42.), ( True,  307.), ( True,  983.),
#        ( True,  120.), ( True, 1525.), (False, 1680.), ( True, 1730.),
#        ( True,  805.), (False, 2388.), ( True,  559.), (False, 1977.),
#        ( True,  476.), (False, 1514.), (False, 1617.), ( True, 1094.),
#        ( True,  784.), ( True,  181.), ( True,  415.), ( True, 1120.),
#        ( True,  316.), ( True,  637.), ( True,  247.), (False,  888.),
#        ( True,  622.), (False,  806.), (False, 1163.), (False, 1721.),
#        (False,  741.), ( True,  372.), (False, 1331.), ( True,  394.),
#        (False,  652.), (False,  657.), (False,  567.), (False,  429.),
#        (False,  566.), (False,   15.), ( True,   98.), (False,  368.),
#        (False,  432.), (False,  319.), (False,   65.), (False,   16.),
#        (False,   29.), (False,   18.), (False,   17.), ( True,  308.),
#        (False, 1965.), ( True,  548.), ( True,  293.), (False, 2017.),
#        (False, 1093.), (False,  792.), ( True,  586.), (False, 1434.),
#        (False,   67.), (False,  623.), (False, 2128.), (False, 1965.),
#        (False, 2161.), ( True, 1183.), ( True, 1108.), (False, 2065.),
#        (False, 1598.), ( True,  491.), ( True, 1366.), (False,  424.),
#        ( True,  859.), ( True,  180.), (False, 1625.), (False, 1938.),
#        ( True, 1343.), ( True,  646.), (False, 2192.), ( True,  502.),
#        (False, 1675.), ( True, 1363.), ( True,  420.), ( True,  982.),
#        (False, 1459.), (False, 1192.), (False, 1264.), (False, 1095.),
#        (False, 1078.), (False,  737.), (False,  461.), ( True,  465.),
#        ( True,  842.), (False,  918.), ( True,  374.), (False, 1089.),
#        (False, 1527.), ( True,  285.), ( True, 1306.), ( True,  797.),
#        (False, 1441.), ( True,  343.), (False,  936.), (False,  195.),
#        ( True,  503.), ( True,  827.), (False, 1427.), (False,  854.),
#        ( True,  177.), ( True,  281.), ( True,  205.), (False,  751.),
#        ( True,  629.), (False,  526.), (False,  463.), (False,  529.),
#        (False,  623.), (False,  546.), (False,  213.), (False,  276.),
#        (False, 2010.), (False, 2009.), (False, 1984.), (False, 1981.),
#        ( True,  624.), ( True,  742.), (False, 1818.), ( True, 1493.),
#        (False, 1432.), ( True,  801.), (False, 1182.), (False,   71.),
#        (False,  114.), (False,   63.), (False, 1722.), (False, 1692.),
#        (False,  177.), (False,   57.), (False, 1152.), (False,  733.),
#        ( True, 1459.), (False, 2237.), (False,  933.), (False, 2056.),
#        (False, 1729.), (False, 2024.), ( True, 2039.), (False, 2027.),
#        (False, 2007.), ( True, 1253.), (False, 1789.), (False, 1707.),
#        (False, 1714.), (False, 1717.), ( True,  329.), (False, 1624.),
#        (False, 1600.), ( True,  385.), (False, 1475.), (False, 1435.),
#        (False,  541.), (False, 1329.), (False, 1357.), (False, 1343.),
#        ( True,  748.), ( True, 1090.), (False, 1219.), (False,  553.),
#        ( True,  662.), (False,  969.), (False,  974.), ( True,  866.),
#        ( True,  504.), (False,  721.), (False,  186.), ( True,  769.),
#        ( True,  727.), ( True, 1701.)],
#       dtype=[('cens', '?'), ('time', '<f8')])

# %% [markdown]
# 데이터 전처리

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 686 entries, 0 to 685
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       686 non-null    float64
#  1   estrec    686 non-null    float64
#  2   horTh     686 non-null    category
#  3   menostat  686 non-null    category
#  4   pnodes    686 non-null    float64
#  5   progrec   686 non-null    float64
#  6   tgrade    686 non-null    category
#  7   tsize     686 non-null    float64
# dtypes: category(3), float64(5)
# memory usage: 29.3 KB

# %%
# 데이터 타입을 바꿔줌
grade_str = X.loc[:, "tgrade"].astype(object).values[:, np.newaxis] # np.newaxis : 차원을 늘려줌
# 0, 1, 2 로 바꿔주는 엔코더
grade_num = OrdinalEncoder(categories=[["I", "II", "III"]]).fit_transform(grade_str)

X_no_grade = X.drop("tgrade", axis=1)
Xt = OneHotEncoder().fit_transform(X_no_grade) # 바이너리 데이터 0,1 로 변경해줌
Xt.loc[:, "tgrade"] = grade_num # tgrade에 0, 1, 2로 변경해준 값 넣어줌

# %%
Xt.head()
# Out:
#     age  estrec  horTh=yes  menostat=Post  pnodes  progrec  tsize  tgrade
# 0  70.0    66.0        0.0            1.0     3.0     48.0   21.0     1.0
# 1  56.0    77.0        1.0            1.0     7.0     61.0   12.0     1.0
# 2  58.0   271.0        1.0            1.0     9.0     52.0   35.0     1.0
# 3  59.0    29.0        1.0            1.0     4.0     60.0   17.0     1.0
# 4  73.0    65.0        0.0            1.0     1.0     26.0   35.0     1.0

# %%
y
# Out:
# array([( True, 1814.), ( True, 2018.), ( True,  712.), ( True, 1807.),
#        ( True,  772.), ( True,  448.), (False, 2172.), (False, 2161.),
#        ( True,  471.), (False, 2014.), ( True,  577.), ( True,  184.),
#        (False, 1840.), (False, 1842.), (False, 1821.), ( True, 1371.),
#        ( True,  707.), (False, 1743.), (False, 1781.), ( True,  865.),
#        ( True, 1684.), (False, 1701.), (False, 1701.), (False, 1693.),
#        ( True,  379.), ( True, 1105.), ( True,  548.), ( True, 1296.),
#        (False, 1483.), (False, 1570.), (False, 1469.), (False, 1472.),
#        (False, 1342.), (False, 1349.), ( True, 1162.), (False, 1342.),
#        ( True,  797.), (False, 1232.), (False, 1230.), (False, 1205.),
#        (False, 1090.), (False, 1095.), ( True,  449.), (False,  972.),
#        (False,  825.), (False, 2438.), (False, 2233.), ( True,  286.),
#        (False, 1861.), ( True, 1080.), ( True, 1521.), (False, 1693.),
#        ( True, 1528.), ( True,  169.), ( True,  272.), ( True,  731.),
#        (False, 2059.), (False, 1853.), (False, 1854.), (False, 1645.),
#        ( True,  544.), (False, 1666.), ( True,  353.), (False, 1791.),
#        (False, 1685.), ( True,  191.), ( True,  370.), ( True,  173.),
#        ( True,  242.), ( True,  420.), ( True,  438.), (False, 1624.),
#        ( True, 1036.), ( True,  359.), ( True,  171.), ( True,  959.),
#        (False, 1351.), ( True,  486.), ( True,  525.), ( True,  762.),
#        ( True,  175.), (False, 1195.), ( True,  338.), (False, 1125.),
#        (False,  916.), (False,  972.), (False,  867.), ( True,  249.),
#        ( True,  281.), (False,  758.), ( True,  377.), (False, 1976.),
#        (False, 2539.), (False, 2467.), ( True,  876.), (False, 2132.),
#        ( True,  426.), ( True,  554.), ( True, 1246.), (False, 1926.),
#        ( True, 1207.), (False, 1852.), ( True, 1174.), (False, 1250.),
#        ( True,  530.), (False, 1502.), (False, 1364.), ( True, 1170.),
#        (False, 1729.), (False, 1642.), ( True, 1218.), (False, 1358.),
#        ( True,  360.), ( True,  550.), (False,  857.), (False,  768.),
#        (False,  858.), (False,  770.), ( True,  679.), ( True, 1164.),
#        ( True,  350.), ( True,  578.), ( True, 1460.), (False, 1434.),
#        ( True, 1763.), ( True,  889.), ( True,  357.), ( True,  547.),
#        (False, 1722.), (False, 2372.), ( True, 2030.), ( True, 1002.),
#        ( True, 1280.), ( True,  338.), ( True,  533.), (False,  168.),
#        (False, 1169.), ( True, 1675.), (False, 1862.), (False,  629.),
#        (False, 1167.), ( True,  495.), (False,  967.), (False, 1720.),
#        ( True,  598.), ( True,  392.), (False, 1502.), (False,  229.),
#        (False,  310.), (False, 1296.), (False,  488.), (False,  942.),
#        (False,  570.), (False, 1177.), (False, 1113.), ( True,  288.),
#        (False,  723.), ( True,  403.), ( True, 1225.), ( True,  338.),
#        ( True, 1337.), ( True, 1420.), (False, 2048.), ( True,  600.),
#        (False, 1765.), ( True,  491.), ( True,  305.), (False, 1582.),
#        (False, 1771.), ( True,  960.), ( True,  571.), (False,  675.),
#        ( True,  285.), (False, 1472.), ( True, 1279.), (False,  148.),
#        (False, 1863.), (False, 1933.), ( True,  358.), (False,  734.),
#        ( True, 2372.), (False, 2563.), (False, 2372.), ( True, 1989.),
#        ( True, 2015.), (False, 1956.), ( True,  945.), (False, 2153.),
#        ( True,  838.), ( True,  113.), (False, 1833.), (False, 1722.),
#        ( True,  241.), ( True, 1352.), (False, 1702.), (False, 1222.),
#        (False, 1089.), (False, 1243.), ( True,  579.), ( True, 1043.),
#        (False, 2234.), (False, 2297.), (False, 2014.), ( True,  518.),
#        (False,  940.), (False,  766.), ( True,  251.), (False, 1959.),
#        (False, 1897.), ( True,  160.), (False,  970.), (False,  892.),
#        (False,  753.), ( True,  348.), ( True,  275.), ( True, 1329.),
#        ( True, 1193.), ( True,  698.), ( True,  436.), ( True,  552.),
#        ( True,  564.), (False, 2239.), (False, 2237.), ( True,  529.),
#        (False, 1820.), (False, 1756.), ( True,  515.), ( True,  272.),
#        ( True,  891.), (False, 1356.), (False, 1352.), (False, 1077.),
#        ( True,  675.), (False,  855.), (False,  740.), (False, 2551.),
#        ( True,  754.), ( True,  819.), ( True, 1280.), (False, 2388.),
#        (False, 2296.), (False, 1884.), ( True, 1059.), (False,  859.),
#        (False, 1109.), ( True, 1192.), ( True, 1806.), ( True,  500.),
#        ( True, 1589.), ( True, 1463.), (False, 1826.), (False, 1231.),
#        (False, 1117.), ( True,  836.), (False, 1222.), (False,  663.),
#        ( True,  722.), (False,  322.), ( True, 1150.), ( True,  446.),
#        (False, 1855.), ( True,  238.), (False, 1838.), (False, 1826.),
#        ( True, 1093.), (False, 2051.), ( True,  370.), ( True,  861.),
#        ( True, 1587.), ( True,  552.), (False, 2353.), (False, 2471.),
#        ( True,  893.), ( True, 2093.), (False, 2612.), ( True,  956.),
#        (False, 1637.), (False, 2456.), (False, 2227.), ( True, 1601.),
#        (False, 1841.), (False, 2177.), (False, 2052.), (False,  973.),
#        (False, 2156.), (False, 1499.), (False, 2030.), ( True,  573.),
#        (False, 1666.), (False, 1979.), (False, 1786.), (False, 1847.),
#        (False, 2009.), (False, 1926.), (False, 1490.), ( True,  233.),
#        (False, 1240.), (False, 1751.), (False, 1878.), (False, 1171.),
#        (False, 1751.), (False, 1756.), ( True,  714.), (False, 1505.),
#        ( True,  776.), (False, 1443.), (False, 1317.), (False,  870.),
#        ( True,  859.), ( True,  223.), (False, 1212.), (False, 1119.),
#        (False,  740.), (False, 1062.), (False,    8.), (False,  936.),
#        (False,  740.), ( True,  632.), (False, 1760.), (False, 1013.),
#        (False,  779.), ( True,  375.), (False, 1323.), (False, 1233.),
#        (False,  986.), (False,  650.), (False,  628.), (False, 1866.),
#        ( True,  491.), ( True, 1918.), ( True,   72.), ( True, 1140.),
#        ( True,  799.), ( True, 1105.), ( True,  548.), ( True,  227.),
#        (False, 1838.), (False, 1833.), ( True,  550.), ( True,  426.),
#        (False, 1834.), (False, 1604.), (False,  772.), ( True, 1146.),
#        ( True,  371.), ( True,  883.), (False, 1735.), ( True,  554.),
#        ( True,  790.), (False, 1340.), ( True,  490.), (False, 1557.),
#        ( True,  594.), (False,  828.), ( True,  594.), (False,  841.),
#        (False,  695.), (False, 2556.), ( True, 1753.), ( True,  417.),
#        ( True,  956.), (False, 1846.), (False, 1703.), (False, 1720.),
#        (False, 1355.), (False, 1603.), ( True,  476.), (False, 1350.),
#        (False, 1341.), (False, 2449.), ( True, 2286.), ( True,  456.),
#        ( True,  536.), ( True,  612.), ( True, 2034.), ( True, 1990.),
#        ( True, 2456.), (False, 2205.), ( True,  544.), ( True,  336.),
#        (False, 2057.), ( True,  575.), (False, 2011.), ( True,  537.),
#        (False, 2217.), ( True, 1814.), ( True,  890.), (False, 1114.),
#        (False,  974.), (False,  296.), (False, 2320.), ( True,  795.),
#        ( True,  867.), (False, 1703.), ( True,  670.), ( True,  981.),
#        (False, 1094.), ( True,  755.), ( True, 1388.), ( True, 1387.),
#        ( True,  535.), (False, 1653.), (False, 1904.), (False, 1868.),
#        (False, 1767.), ( True,  855.), ( True, 1157.), (False, 1869.),
#        (False, 1152.), (False, 1401.), (False,  918.), ( True,  745.),
#        (False, 1283.), ( True, 1481.), (False, 1807.), ( True,  542.),
#        (False, 1441.), (False, 1277.), (False, 1486.), (False,  273.),
#        ( True,  177.), ( True,  545.), (False, 1185.), (False,  631.),
#        (False,  995.), (False, 1088.), (False,  877.), (False,  798.),
#        (False, 2380.), ( True, 1679.), ( True,  498.), (False, 2138.),
#        (False, 2175.), (False, 2271.), (False,   17.), ( True,  964.),
#        ( True,  540.), ( True,  747.), ( True,  650.), ( True,  410.),
#        ( True,  624.), (False, 1560.), ( True,  455.), (False, 1629.),
#        (False, 1730.), (False, 1483.), ( True,  687.), ( True,  308.),
#        ( True,  563.), (False,   46.), (False, 2144.), ( True,  344.),
#        (False,  945.), (False, 1905.), ( True,  855.), (False, 2370.),
#        (False,  853.), (False,  692.), ( True,  475.), (False, 2195.),
#        (False,  758.), ( True,  648.), (False,  761.), (False,  596.),
#        ( True,  195.), ( True,  473.), (False,  747.), (False, 2659.),
#        ( True, 1977.), (False, 2401.), (False, 1499.), (False, 1856.),
#        ( True,  595.), (False, 2148.), (False, 2126.), ( True, 1975.),
#        ( True, 1641.), (False, 1717.), (False, 1858.), (False, 2049.),
#        ( True, 1502.), (False, 1922.), (False, 1818.), (False, 1100.),
#        (False, 1499.), ( True,  359.), (False, 1645.), (False, 1356.),
#        (False, 1632.), (False,  967.), (False, 1091.), ( True,  918.),
#        ( True,  557.), ( True, 1219.), (False, 2170.), ( True,  729.),
#        ( True, 1449.), ( True,  991.), ( True,  481.), (False, 1655.),
#        ( True,  857.), ( True,  369.), (False, 1627.), (False, 1578.),
#        ( True,  732.), ( True,  460.), (False, 1208.), ( True,  730.),
#        (False,  722.), (False,  717.), (False,  651.), (False,  637.),
#        (False,  615.), (False,   42.), ( True,  307.), ( True,  983.),
#        ( True,  120.), ( True, 1525.), (False, 1680.), ( True, 1730.),
#        ( True,  805.), (False, 2388.), ( True,  559.), (False, 1977.),
#        ( True,  476.), (False, 1514.), (False, 1617.), ( True, 1094.),
#        ( True,  784.), ( True,  181.), ( True,  415.), ( True, 1120.),
#        ( True,  316.), ( True,  637.), ( True,  247.), (False,  888.),
#        ( True,  622.), (False,  806.), (False, 1163.), (False, 1721.),
#        (False,  741.), ( True,  372.), (False, 1331.), ( True,  394.),
#        (False,  652.), (False,  657.), (False,  567.), (False,  429.),
#        (False,  566.), (False,   15.), ( True,   98.), (False,  368.),
#        (False,  432.), (False,  319.), (False,   65.), (False,   16.),
#        (False,   29.), (False,   18.), (False,   17.), ( True,  308.),
#        (False, 1965.), ( True,  548.), ( True,  293.), (False, 2017.),
#        (False, 1093.), (False,  792.), ( True,  586.), (False, 1434.),
#        (False,   67.), (False,  623.), (False, 2128.), (False, 1965.),
#        (False, 2161.), ( True, 1183.), ( True, 1108.), (False, 2065.),
#        (False, 1598.), ( True,  491.), ( True, 1366.), (False,  424.),
#        ( True,  859.), ( True,  180.), (False, 1625.), (False, 1938.),
#        ( True, 1343.), ( True,  646.), (False, 2192.), ( True,  502.),
#        (False, 1675.), ( True, 1363.), ( True,  420.), ( True,  982.),
#        (False, 1459.), (False, 1192.), (False, 1264.), (False, 1095.),
#        (False, 1078.), (False,  737.), (False,  461.), ( True,  465.),
#        ( True,  842.), (False,  918.), ( True,  374.), (False, 1089.),
#        (False, 1527.), ( True,  285.), ( True, 1306.), ( True,  797.),
#        (False, 1441.), ( True,  343.), (False,  936.), (False,  195.),
#        ( True,  503.), ( True,  827.), (False, 1427.), (False,  854.),
#        ( True,  177.), ( True,  281.), ( True,  205.), (False,  751.),
#        ( True,  629.), (False,  526.), (False,  463.), (False,  529.),
#        (False,  623.), (False,  546.), (False,  213.), (False,  276.),
#        (False, 2010.), (False, 2009.), (False, 1984.), (False, 1981.),
#        ( True,  624.), ( True,  742.), (False, 1818.), ( True, 1493.),
#        (False, 1432.), ( True,  801.), (False, 1182.), (False,   71.),
#        (False,  114.), (False,   63.), (False, 1722.), (False, 1692.),
#        (False,  177.), (False,   57.), (False, 1152.), (False,  733.),
#        ( True, 1459.), (False, 2237.), (False,  933.), (False, 2056.),
#        (False, 1729.), (False, 2024.), ( True, 2039.), (False, 2027.),
#        (False, 2007.), ( True, 1253.), (False, 1789.), (False, 1707.),
#        (False, 1714.), (False, 1717.), ( True,  329.), (False, 1624.),
#        (False, 1600.), ( True,  385.), (False, 1475.), (False, 1435.),
#        (False,  541.), (False, 1329.), (False, 1357.), (False, 1343.),
#        ( True,  748.), ( True, 1090.), (False, 1219.), (False,  553.),
#        ( True,  662.), (False,  969.), (False,  974.), ( True,  866.),
#        ( True,  504.), (False,  721.), (False,  186.), ( True,  769.),
#        ( True,  727.), ( True, 1701.)],
#       dtype=[('cens', '?'), ('time', '<f8')])

# %% [markdown]
# <br><br><br>
# Internal split validation 데이터 나누기

# %%
random_state = 20
X_train, X_test, y_train, y_test = train_test_split(Xt, y, test_size=0.25, random_state=random_state)

# %%
print(X_train.shape)
print(y_train.shape)

print(X_test.shape)
print(y_test.shape)
# Out:
# (514, 8)
# (514,)
# (172, 8)
# (172,)

# %% [markdown]
# <br><br><br>
# Random Forest인데, split rule이 log-rank일 뿐인 알고리즘

# %%
rsf = RandomSurvivalForest(n_estimators=1000,
                           min_samples_split=10,
                           min_samples_leaf=15,
                           max_features="sqrt",
                           n_jobs=-1,
                           random_state=random_state)

rsf.fit(X_train, y_train)
# Out:
# RandomSurvivalForest(max_features='sqrt', min_samples_leaf=15,
#                      min_samples_split=10, n_estimators=1000, n_jobs=-1,
#                      random_state=20)

# %%
X_test
# Out:
#       age  estrec  horTh=yes  menostat=Post  pnodes  progrec  tsize  tgrade
# 14   70.0   139.0        1.0            1.0     3.0    113.0   22.0     1.0
# 270  46.0    49.0        0.0            0.0     1.0      6.0   12.0     1.0
# 226  72.0  1091.0        1.0            1.0    36.0      2.0   34.0     2.0
# 636  50.0    60.0        0.0            0.0     2.0    323.0   29.0     0.0
# 434  50.0     4.0        0.0            0.0     1.0      1.0   18.0     2.0
# ..    ...     ...        ...            ...     ...      ...    ...     ...
# 31   36.0     5.0        0.0            0.0     2.0      6.0   44.0     2.0
# 358  51.0    89.0        0.0            0.0     1.0     77.0   20.0     1.0
# 357  47.0    45.0        1.0            0.0     3.0    195.0   30.0     0.0
# 644  45.0     4.0        0.0            0.0     1.0      0.0   25.0     2.0
# 105  48.0     0.0        0.0            0.0     7.0      8.0   70.0     1.0
#
# [172 rows x 8 columns]

# %%
rsf.score(X_test, y_test)
# Out:
# 0.6759696016771488

# %%
rsf.predict(X_test) # 리스크 수치  출력
# Out:
# array([ 30.48857937,  51.10857391, 148.69183517,  38.16129097,
#         91.44590567,  62.10453632,  26.52193036,  97.15142192,
#         95.53614184,  29.06335827,  23.48722082,  62.70842942,
#         79.31593907,  41.83593395, 118.46712242,  52.00776762,
#         54.54620921,  76.52632792, 169.3626459 , 180.09783904,
#        152.00327962, 101.01233195,  63.31959955, 135.84213225,
#         92.69888459,  94.29951525,  43.98081866,  43.3527616 ,
#         61.25776562,  56.7742065 ,  43.21053694, 153.48737298,
#         49.7054088 , 131.44057413,  58.28396746,  57.15191011,
#        175.18013102,  73.19537819,  89.6767838 ,  41.74420722,
#         45.62088346,  35.96978975, 124.8756294 , 174.16282978,
#         29.16624668, 113.65324278, 120.32640045, 141.10109736,
#         43.24724335,  60.46976124,  45.17618218, 162.12189729,
#         45.46867297,  41.56685206,  97.26381995, 108.80511072,
#         57.86610052,  32.02489704,  49.78109738,  48.69608491,
#         31.97347385,  51.57422786, 159.66446656,  87.29014872,
#        159.94472085,  40.5676566 , 102.56993728,  49.7044509 ,
#        118.21507726,  30.69504045,  49.05703245,  75.70539816,
#        108.99212467, 102.89755213,  81.8256462 ,  55.86108063,
#         65.31672197,  46.67761733,  75.88378635,  64.04547166,
#         51.58542494,  27.05814212,  69.15940785,  35.88388747,
#         33.88466758, 102.16887705, 137.73864207, 166.20534466,
#         73.64490119,  51.72045842,  43.85579919,  58.29772738,
#         69.5263839 ,  84.85829471,  60.53951422,  73.5781436 ,
#         76.92158097,  56.94122682,  51.06488161,  44.89190838,
#        157.66832237, 169.82612392, 171.21006558,  51.76589363,
#        118.43119611,  78.41669207,  97.4754872 ,  37.83170052,
#         84.34530808,  91.49787301,  51.71257663, 106.13437475,
#         62.83309668, 105.30873208,  29.8186764 ,  47.70575118,
#         58.11348553, 173.5268386 ,  54.98541695, 164.63589278,
#        121.53553388,  91.47760868, 117.69537644,  61.8672181 ,
#         90.13348839, 168.31154639, 100.87113532,  39.49274248,
#         47.92908731,  72.83662373,  83.33216867,  59.10904646,
#        109.00204968,  57.83684006,  58.01487569,  27.90262058,
#         60.1767339 ,  65.6798581 ,  44.80085328,  45.10972769,
#         21.92804582, 115.14836584,  88.26645655,  33.49881503,
#         51.91495122,  45.3654078 , 124.73356118,  48.96818177,
#         97.8370553 ,  24.70596772,  54.64907178,  50.97014696,
#         91.32496717,  82.95399104, 112.86271991,  32.36747285,
#         43.71311896,  42.50267078,  40.41885094,  42.27284638,
#        170.50209197, 128.65388473,  38.3747271 ,  46.60856588,
#        112.33388885,  38.48452061,  68.37903421, 103.58997371,
#         52.87453353,  30.21996053, 100.05624748, 152.34973718])

# %%
PredRes = pd.Series(rsf.predict(X_test))

# %%
PredRes.describe()
# Out:
# count    172.000000
# mean      78.353405
# std       41.470165
# min       21.928046
# 25%       45.582831
# 50%       62.770763
# 75%      102.651841
# max      180.097839
# dtype: float64

# %%
y_test
# Out:
# array([(False, 1821.), (False, 2353.), ( True,  515.), (False, 1432.),
#        (False,   17.), (False, 1868.), (False, 1781.), (False,  463.),
#        (False, 1078.), ( True, 1090.), (False,  461.), ( True,  495.),
#        (False,  936.), ( True,  646.), ( True,  577.), (False,  740.),
#        (False, 1264.), (False, 1088.), (False, 1751.), (False,  973.),
#        ( True,  420.), (False, 1720.), (False,  798.), ( True,  358.),
#        ( True,  473.), (False, 2059.), (False, 1171.), (False, 1933.),
#        (False, 1182.), ( True, 1253.), (False, 1632.), ( True,  859.),
#        (False, 2011.), (False,  751.), (False, 1231.), (False,  148.),
#        (False,  546.), ( True,  491.), ( True,  732.), (False,  892.),
#        (False, 2014.), (False, 2539.), ( True,  790.), ( True,  595.),
#        ( True,  876.), ( True,  981.), (False,  740.), ( True,  251.),
#        (False, 1329.), (False, 1905.), (False, 1853.), (False, 1167.),
#        (False, 1720.), (False, 1364.), ( True,  343.), ( True,  175.),
#        (False, 1499.), (False, 2237.), (False, 1483.), (False,  229.),
#        ( True,  799.), ( True,  687.), (False, 2014.), ( True,  578.),
#        ( True,  548.), (False,  967.), (False, 1469.), ( True,  795.),
#        (False, 1013.), (False, 1514.), (False, 1717.), ( True, 2018.),
#        ( True,  113.), ( True, 1108.), (False, 1869.), (False,  870.),
#        (False, 1842.), (False, 1219.), ( True,  545.), (False, 1472.),
#        (False, 2438.), (False, 1152.), ( True,  707.), ( True,  594.),
#        ( True,  548.), ( True, 1366.), (False,   16.), ( True,  377.),
#        ( True,  486.), ( True, 1525.), ( True,  714.), (False, 2205.),
#        (False,  721.), (False, 1192.), ( True,  285.), ( True,  371.),
#        (False, 1965.), (False, 2380.), (False, 1208.), (False, 2057.),
#        ( True,  490.), ( True,  859.), ( True,  471.), ( True,  552.),
#        ( True, 1183.), (False, 1570.), (False,  488.), (False, 2161.),
#        ( True,  542.), (False, 2128.), (False, 1317.), ( True, 1080.),
#        (False, 1427.), (False,  772.), (False, 1717.), (False, 1866.),
#        ( True,  805.), ( True,  842.), (False, 1600.), ( True,  316.),
#        (False, 1357.), ( True, 1164.), ( True,  305.), (False,  854.),
#        ( True,  181.), (False, 1441.), ( True, 2456.), (False, 1342.),
#        ( True, 1120.), (False, 1645.), ( True,  867.), (False, 1976.),
#        (False, 1855.), (False, 2372.), (False, 1169.), (False, 1499.),
#        (False, 2009.), (False, 1233.), (False,  637.), ( True, 1807.),
#        (False, 2372.), (False, 1603.), (False,   67.), ( True, 1219.),
#        ( True, 1528.), (False,  940.), (False, 1791.), ( True,  353.),
#        (False, 1878.), (False, 1356.), ( True, 2286.), (False, 1624.),
#        (False, 1062.), ( True,  177.), ( True,  275.), (False, 1701.),
#        (False, 1527.), (False,  195.), (False, 1693.), (False,  692.),
#        ( True,  379.), ( True,  855.), (False, 1617.), (False, 2170.),
#        ( True,  285.), (False, 1243.), ( True, 1814.), (False, 1472.),
#        ( True, 1753.), (False, 2556.), (False,  177.), (False, 1502.)],
#       dtype=[('cens', '?'), ('time', '<f8')])

# %%
Event, Time = [], []
for Surv in y_test:
    Event.append(Surv[0])
    Time.append(Surv[1])

# %%
FinalPred = pd.DataFrame({
    'Event':Event,
    'Time':Time,
    'Prediction':PredRes>78 # 평균 78초과로 구분
})

FinalPred
# Out:
#      Event    Time  Prediction
# 0    False  1821.0       False
# 1    False  2353.0       False
# 2     True   515.0        True
# 3    False  1432.0       False
# 4    False    17.0        True
# ..     ...     ...         ...
# 167  False  1472.0        True
# 168   True  1753.0       False
# 169  False  2556.0       False
# 170  False   177.0        True
# 171  False  1502.0        True
#
# [172 rows x 3 columns]

# %%
from lifelines import KaplanMeierFitter

treat1 = FinalPred[FinalPred['Prediction'] == True]
treat2 = FinalPred[FinalPred['Prediction'] == False]

kmf = KaplanMeierFitter()
kmf.fit(treat1['Time'], treat1['Event'], label='High-risk')
ax_kmf = kmf.plot(show_censors=True)
kmf.fit(treat2['Time'], treat2['Event'], label='Low-risk')
ax_kmf = kmf.plot(ax = ax_kmf, show_censors=True)

ax_kmf.set_xlabel('Time (Months)')
ax_kmf.set_ylabel('Survival Rate')
ax_kmf
# Out:
# <AxesSubplot:xlabel='Time (Months)', ylabel='Survival Rate'>
